# %%
import pandas as pd
file_path = r"C:\data\globalfund_cartography\raw\kwango\Kwango part 1\donn‚es cartographie restantes\carto zs kitenda\DONNEES CARTOGRAPHIE ZS KITENDA-Fleming\DONNEES CARTOGRAPHIE ZSR de KITENDA 2.xlsx"
df = pd.read_excel(file_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               430 non-null    object
#  1   Unnamed: 1                               505 non-null    object
#  2   FICHE DE TERRAIN ZONE RURALE DE KITENDA  429 non-null    object
#  3   Unnamed: 3                               254 non-null    object
#  4   Unnamed: 4                               427 non-null    object
#  5   Unnamed: 5                               427 non-null    object
#  6   Unnamed: 6                               427 non-null    object
#  7   Unnamed: 7                               173 non-null    object
#  8   Unnamed: 8                               418 non-null    object
# dtypes: object(9)
# memory usage: 37.2+ KB

# %%
df.head()
# Out:
#   Unnamed: 0          Unnamed: 1 FICHE DE TERRAIN ZONE RURALE DE KITENDA  \
# 0        NaN  Nom du Responsable                                     NaN
# 1        NaN       Aire de Santé                                     NaN
# 2        NaN       Zone de Santé                                     NaN
# 3        NaN                Date                                     NaN
# 4        NaN            Appareil                                     NaN
#
#             Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0       ININGA KAHUMBA        NaN        NaN        NaN        NaN        NaN
# 1              KITENDA        NaN        NaN        NaN        NaN        NaN
# 2              KITENDA        NaN        NaN        NaN        NaN        NaN
# 3  2019-06-19 00:00:00        NaN        NaN        NaN        NaN        NaN
# 4   GPS ETREX 10 FM 48        NaN        NaN        NaN        NaN        NaN

# %%
df.isna().sum()
# Out:
# Unnamed: 0                                  98
# Unnamed: 1                                  23
# FICHE DE TERRAIN ZONE RURALE DE KITENDA     99
# Unnamed: 3                                 274
# Unnamed: 4                                 101
# Unnamed: 5                                 101
# Unnamed: 6                                 101
# Unnamed: 7                                 355
# Unnamed: 8                                 110
# dtype: int64

# %%
# Drop na to look at a full row
complete_df = df.dropna()
complete_df.head()
# Out:
#    Unnamed: 0                Unnamed: 1  \
# 6    N° WAYPT           Nom de l'entité
# 8         003              ITM/Kitanoda
# 9         004                  HGR/KTDA
# 13        008                 EP KIVUVU
# 14        009  Terrain  de foot KITENDA
#
#    FICHE DE TERRAIN ZONE RURALE DE KITENDA  \
# 6                                     Type
# 8                                      ITM
# 9                               Répere Géo
# 13                                      EP
# 14                                      IP
#
#                                     Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 6                                  Observation   Territoire     Secteur
# 8                                    G:13;F:21  Kasong-lunda  swa/tenda
# 9   2Médecins,14 Infirmiers,64Lits,1Echographe  Kasong-lunda  swa/tenda
# 13                                 G:149;F:132  Kasong-lunda  swa/tenda
# 14                                   G:87;F:69  Kasong-lunda  swa/tenda
#
# ...

# %%
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 6 to 503
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               124 non-null    object
#  1   Unnamed: 1                               124 non-null    object
#  2   FICHE DE TERRAIN ZONE RURALE DE KITENDA  124 non-null    object
#  3   Unnamed: 3                               124 non-null    object
#  4   Unnamed: 4                               124 non-null    object
#  5   Unnamed: 5                               124 non-null    object
#  6   Unnamed: 6                               124 non-null    object
#  7   Unnamed: 7                               124 non-null    object
#  8   Unnamed: 8                               124 non-null    object
# dtypes: object(9)
# memory usage: 9.7+ KB

# %%
import geopandas as gpd

file_path = r"C:\data\globalfund_cartography\processed\SUD_UBANGI_NDOME_Health_Zones\SUD_UBANGI_NDOME_Health_Zones\NDOMBE_Health_Zone_joined\ZS_BANZOV_FM12_FM17_Mai_joined.shp"
data = gpd.read_file(file_path)

# %%
data.head()
# Out:
#    OBJECTID  Id Name Descript Type Comment      Symbol             DateTimeS  \
# 0         1   0  001     None  WPT    None  Flag, Blue  2019-05-04T10:20:30Z
# 1         2   0  002     None  WPT    None  Flag, Blue  2019-05-04T10:33:09Z
# 2         3   0  003     None  WPT    None  Flag, Blue  2019-05-04T10:39:20Z
# 3         4   0  004     None  WPT    None  Flag, Blue  2019-05-04T10:49:41Z
# 4         5   0  005     None  WPT    None  Flag, Blue  2019-05-04T10:57:40Z
#
#     Elevation  Name1  ...    SECTEUR GROUPEMENT    APPATENANC  \
# 0  322.129395      1  ...  BASENGELE     MPENGE          ETAT
# 1  317.793732      2  ...  BASENGELE     MPENGE          ETAT
# 2  324.159485      3  ...  BASENGELE     MPENGE          ETAT
# 3  322.127655      4  ...  BASENGELE     MPENGE  KIMBANGUISTE
# 4  320.516174      5  ...  BASENGELE     MPENGE          ETAT
#
#           NOM_RESPON   AIRE_DE_SA   ZONE_DE_SA        DATE APPAREIL_G  \
# ...

# %%
data.plot()

# %%
# from arcgis.gis import GIS
# my_gis = GIS()
# m = my_gis.map()
# m
