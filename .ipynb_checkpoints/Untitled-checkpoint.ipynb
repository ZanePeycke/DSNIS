# %% [markdown]
# ## Cleaning DSNIS Data:
# #### We begin by loading our excel file and reading it into a pandas dataframe

# %%
import pandas as pd
file_path = r"C:\Users\Zane Peycke\proj\grid3\data\donnes_cartographie_kitenda_1_copy.xlsx"
df = pd.read_excel(file_path, header=None)

# %% [markdown]
# #### Remove all rows that are completely empty
# ##### (The original excel files contain empty rows between different areas etc. in a single sheet)

# %%
df.dropna(how='all', inplace=True)
df.ffill(inplace=True)
# We reset the numerical index to find our split points later
df.reset_index(inplace=True)

# %% [markdown]
# #### We need to reformat information including nom, arie, zone, date for each group of data.
# ##### To do this we will begin by separating blocks when 'Nom du Superviseur' occurs in a sheet

# %%
index_list = []
string = 'NOM DU SUPERVISEUR'
for index in range(len(df.index)):
    if df.iloc[index].str.contains(string).any()== True:
        index_list.append(index)

# %%
df_list = []
for i in range(len(index_list)-1):
    df_current = df.iloc[index_list[i]:index_list[i+1]]
    df_list.append(df_current)
#     print(f'{index_list[i]} {index_list[i+1]}')

# %%
len(df_list)
# Out:
# 8

# %%
df_list[0]
# Out:
#     index                                          0         1  \
# 0       0                         NOM DU SUPERVISEUR       NaN
# 1       1            AIRE DE SANTE                 :       NaN
# 2       2              ZONE DE SANTE               :       NaN
# 3       3  DATE                                    :       NaN
# 4       4                NUMERO DE GPS             :       NaN
# 5       5                                        N°   LATITUDE
# 6       6                                        001  LATITUDE
# 7       7                                        002  LATITUDE
# 8       8                                        003  LATITUDE
# 9       9                                        004  LATITUDE
# 10     10                                        005  LATITUDE
# 11     11                                        006  LATITUDE
# 12     12                                        007  LATITUDE
# 13     13                                        008  LATITUDE
# 14     14                                        009  LATITUDE
# 15     15                                        010  LATITUDE
# 16     16                                        011  LATITUDE
# 17     17                                        012  LATITUDE
# 18     18                                        013  LATITUDE
# 19     19                                        014  LATITUDE
# 20     20                                        015  LATITUDE
# 21     21                                        016  LATITUDE
# 22     22                                        017  LATITUDE
# 23     23                                        018  LATITUDE
# 24     24                                        019  LATITUDE
# 25     25                                        020  LATITUDE
# 26     26                                        021  LATITUDE
# 27     27                                        022  LATITUDE
# 28     28                                        023  LATITUDE
# 29     29                                        024  LATITUDE
# 30     30                                        026  LATITUDE
# 31     31                                        027  LATITUDE
# 32     32                                        028  LATITUDE
# 33     33                                        029  LATITUDE
# 34     34                                        030  LATITUDE
# 35     35                                        031  LATITUDE
# 36     36                                        032  LATITUDE
# 37     37                                        035  LATITUDE
# 38     38                                        036  LATITUDE
# 39     39                                        037  LATITUDE
# 40     40                                        038  LATITUDE
# 41     41                                        040  LATITUDE
#
#                       2                               3        4  \
# 0    MUSANDA NGUBA HENZ                             NaN      NaN
# 1                 BAMBA                             NaN      NaN
# 2               KITENDA                             NaN      NaN
# 3   2019-06-19 00:00:00                             NaN      NaN
# 4              FM    47                             NaN      NaN
# 5             LONGITUDE                  NOM D'IDENTITE     TYPE
# 6             LONGITUDE                 VILLAGE MAKONGA  VILLAGE
# 7             LONGITUDE        EGLISE CATHOLOIQUE BAMBA       IP
# 8             LONGITUDE              EGLISE CEK MAKONGA       IP
# 9             LONGITUDE           INSTITUT CEK MAKONGA      INST
# 10            LONGITUDE               EP MAKABU MAZEMBE       EP
# 11            LONGITUDE       EGLISE TEMOINS DE JEHOVAH       IP
# 12            LONGITUDE                      EP KALUNGA       EP
# 13            LONGITUDE                Vill  KINGANGULA  VILLAGE
# 14            LONGITUDE            INSTITUT KIALA BAMBA     INST
# 15            LONGITUDE  EGLISE ASSEMBLEE DE DIEU BAMBA       IP
# 16            LONGITUDE                        EP BAMBA       EP
# 17            LONGITUDE                       INST ITAV     INST
# 18            LONGITUDE                    EP CEK BAMBA       EP
# 19            LONGITUDE                EGLISE CEK BAMBA       IP
# 20            LONGITUDE                        CS BAMBA       CS
# 21            LONGITUDE             EGLISE CATHOL BAMBA       EP
# 22            LONGITUDE       institut catholique BAMBA       IP
# 23            LONGITUDE               VILLAGE KITSAKALA  VILLAGE
# 24            LONGITUDE             EGLISE FEPACO BAMBA       IP
# 25            LONGITUDE                  VILLAGE N'SELE  VILLAGE
# 26            LONGITUDE                EGLISE AJV BAMBA       IP
# 27            LONGITUDE                VILLAGE N'SELE 2    HAMAU
# 28            LONGITUDE              VILLAGE KIMBATSEKE  VILLAGE
# 29            LONGITUDE                   SAVANE MBAMBA  REP GEO
# 30            LONGITUDE                      PS MAKONDO       PS
# 31            LONGITUDE                 VILLAGE MAKONDO  VILLAGE
# 32            LONGITUDE          Eglise message de Dieu       IP
# 33            LONGITUDE                 INSTITUT MAKAWA     INST
# 34            LONGITUDE                      EP MAKONDO       EP
# 35            LONGITUDE              EGLISE CEK MAKONDO       IP
# 36            LONGITUDE                 VILLAGE TSIYENO   LIMITE
# 37            LONGITUDE                VILLAGE KINGONGA   LIMITE
# 38            LONGITUDE          EGLISE FEPACO/KINGONGA       IP
# 39            LONGITUDE                       EP MEDITA       EP
# 40            LONGITUDE               EGLISE CATHOLIQUE       IP
# 41            LONGITUDE                  SAVANE MAKONDO  REP GEO
#
#                                                   5  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                       OBSERVATION
# 6                                       OBSERVATION
# 7                                       OBSERVATION
# 8                                       OBSERVATION
# 9                               G:  33         F:41
# 10                              G:  50         F:58
# 11                              G:  50         F:58
# 12                              G:   28        F:39
# 13                              G:   28        F:39
# 14                              G:86           F:74
# 15                              G:86           F:74
# 16                           G: 124          F: 137
# 17                              G:  15        F: 37
# 18                               G:  99       F: 65
# 19                               G:  99       F: 65
# 20  INF: 5  ACC:2  autres: 3 Mocroscope: 1 lits : 5
# 21  INF: 5  ACC:2  autres: 3 Mocroscope: 1 lits : 5
# 22                              G: 23          F:31
# 23                              G: 23          F:31
# 24                              G: 23          F:31
# 25                              G: 23          F:31
# 26                              G: 23          F:31
# 27                              G: 23          F:31
# 28                              G: 23          F:31
# 29                              G: 23          F:31
# 30                                  INF 1, AUXILL 1
# 31                                  INF 1, AUXILL 1
# 32                                  INF 1, AUXILL 1
# 33                            G= 35            F=30
# 34                              G:   42        F:60
# 35                              G:   42        F:60
# 36                    LIMITES AS BAMBA & AS MAKENZI
# 37                    LIMITES AS BAMBA & AS KITENDA
# 38                    LIMITES AS BAMBA & AS KITENDA
# 39                            G= 43            F=57
# 40                            G= 43            F=57
# 41                            G= 43            F=57
#
#                                  6              7           8  \
# 0   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 1   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 2   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 3   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 4   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 5                       TERRITOIRE        SECTEUR  GROUPEMENT
# 6                    KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 7                    KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 8                    KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 9                    KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 10                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 11                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 12                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 13                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 14                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 15                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 16                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 17                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 18                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 19                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 20                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 21                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 22                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 23                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 24                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 25                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 26                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 27                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 28                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 29                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 30                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 31                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 32                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 33                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 34                   KASONGO LUNDA        KINGULU      POKOSO
# 35                   KASONGO LUNDA        KINGULU      POKOSO
# 36                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 37                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 38                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 39                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 40                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 41                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
#
#                      9             10
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
# 5         APPARTENANCE  ACCESSIBILITE
# 6         APPARTENANCE       VEHICULE
# 7           CATHOLIQUE       VEHICULE
# 8     CONV PROTESTANTE       VEHICULE
# 9                 ETAT       VEHICULE
# 10   CONV KIMBANGUISTE       VEHICULE
# 11  TEMOINS DE JEHOVAH       VEHICULE
# 12                ETAT       VEHICULE
# 13                ETAT       VEHICULE
# 14                ETAT       VEHICULE
# 15                ETAT       VEHICULE
# 16                ETAT       VEHICULE
# 17    CONV PROTESTANTE       VEHICULE
# 18    CONV PROTESTANTE       VEHICULE
# 19    CONV PROTESTANTE       VEHICULE
# 20                ETAT       VEHICULE
# 21          CATHOLIQUE       VEHICULE
# 22    CONV PROTESTANTE       VEHICULE
# 23    CONV PROTESTANTE       VEHICULE
# 24    CONV PROTESTANTE       VEHICULE
# 25    CONV PROTESTANTE       VEHICULE
# 26              REVEIL       VEHICULE
# 27              REVEIL       VEHICULE
# 28              REVEIL       VEHICULE
# 29              REVEIL       VEHICULE
# 30                ETAT       VEHICULE
# 31                ETAT       VEHICULE
# 32              REVEIL       VEHICULE
# 33          PROTESTANT       VEHICULE
# 34          PROTESTANT       VEHICULE
# 35          PROTESTANT       VEHICULE
# 36          PROTESTANT       VEHICULE
# 37          PROTESTANT       VEHICULE
# 38              REVEIL       VEHICULE
# 39          PROTESTANT       VEHICULE
# 40         CONV CATHOL       VEHICULE
# 41         CONV CATHOL       VEHICULE

# %%
df.head(50)
# Out:
#     index                                          0         1  \
# 0       0                         NOM DU SUPERVISEUR       NaN
# 1       1            AIRE DE SANTE                 :       NaN
# 2       2              ZONE DE SANTE               :       NaN
# 3       3  DATE                                    :       NaN
# 4       4                NUMERO DE GPS             :       NaN
# 5       5                                        N°   LATITUDE
# 6       6                                        001  LATITUDE
# 7       7                                        002  LATITUDE
# 8       8                                        003  LATITUDE
# 9       9                                        004  LATITUDE
# 10     10                                        005  LATITUDE
# 11     11                                        006  LATITUDE
# 12     12                                        007  LATITUDE
# 13     13                                        008  LATITUDE
# 14     14                                        009  LATITUDE
# 15     15                                        010  LATITUDE
# 16     16                                        011  LATITUDE
# 17     17                                        012  LATITUDE
# 18     18                                        013  LATITUDE
# 19     19                                        014  LATITUDE
# 20     20                                        015  LATITUDE
# 21     21                                        016  LATITUDE
# 22     22                                        017  LATITUDE
# 23     23                                        018  LATITUDE
# 24     24                                        019  LATITUDE
# 25     25                                        020  LATITUDE
# 26     26                                        021  LATITUDE
# 27     27                                        022  LATITUDE
# 28     28                                        023  LATITUDE
# 29     29                                        024  LATITUDE
# 30     30                                        026  LATITUDE
# 31     31                                        027  LATITUDE
# 32     32                                        028  LATITUDE
# 33     33                                        029  LATITUDE
# 34     34                                        030  LATITUDE
# 35     35                                        031  LATITUDE
# 36     36                                        032  LATITUDE
# 37     37                                        035  LATITUDE
# 38     38                                        036  LATITUDE
# 39     39                                        037  LATITUDE
# 40     40                                        038  LATITUDE
# 41     41                                        040  LATITUDE
# 42     44                         NOM DU SUPERVISEUR  LATITUDE
# 43     45            AIRE DE SANTE                 :  LATITUDE
# 44     46              ZONE DE SANTE               :  LATITUDE
# 45     47  DATE                                    :  LATITUDE
# 46     48                NUMERO DE GPS             :  LATITUDE
# 47     49                                             LATITUDE
# 48     50                                        041  LATITUDE
# 49     51                                        042  LATITUDE
#
#                       2                               3        4  \
# 0    MUSANDA NGUBA HENZ                             NaN      NaN
# 1                 BAMBA                             NaN      NaN
# 2               KITENDA                             NaN      NaN
# 3   2019-06-19 00:00:00                             NaN      NaN
# 4              FM    47                             NaN      NaN
# 5             LONGITUDE                  NOM D'IDENTITE     TYPE
# 6             LONGITUDE                 VILLAGE MAKONGA  VILLAGE
# 7             LONGITUDE        EGLISE CATHOLOIQUE BAMBA       IP
# 8             LONGITUDE              EGLISE CEK MAKONGA       IP
# 9             LONGITUDE           INSTITUT CEK MAKONGA      INST
# 10            LONGITUDE               EP MAKABU MAZEMBE       EP
# 11            LONGITUDE       EGLISE TEMOINS DE JEHOVAH       IP
# 12            LONGITUDE                      EP KALUNGA       EP
# 13            LONGITUDE                Vill  KINGANGULA  VILLAGE
# 14            LONGITUDE            INSTITUT KIALA BAMBA     INST
# 15            LONGITUDE  EGLISE ASSEMBLEE DE DIEU BAMBA       IP
# 16            LONGITUDE                        EP BAMBA       EP
# 17            LONGITUDE                       INST ITAV     INST
# 18            LONGITUDE                    EP CEK BAMBA       EP
# 19            LONGITUDE                EGLISE CEK BAMBA       IP
# 20            LONGITUDE                        CS BAMBA       CS
# 21            LONGITUDE             EGLISE CATHOL BAMBA       EP
# 22            LONGITUDE       institut catholique BAMBA       IP
# 23            LONGITUDE               VILLAGE KITSAKALA  VILLAGE
# 24            LONGITUDE             EGLISE FEPACO BAMBA       IP
# 25            LONGITUDE                  VILLAGE N'SELE  VILLAGE
# 26            LONGITUDE                EGLISE AJV BAMBA       IP
# 27            LONGITUDE                VILLAGE N'SELE 2    HAMAU
# 28            LONGITUDE              VILLAGE KIMBATSEKE  VILLAGE
# 29            LONGITUDE                   SAVANE MBAMBA  REP GEO
# 30            LONGITUDE                      PS MAKONDO       PS
# 31            LONGITUDE                 VILLAGE MAKONDO  VILLAGE
# 32            LONGITUDE          Eglise message de Dieu       IP
# 33            LONGITUDE                 INSTITUT MAKAWA     INST
# 34            LONGITUDE                      EP MAKONDO       EP
# 35            LONGITUDE              EGLISE CEK MAKONDO       IP
# 36            LONGITUDE                 VILLAGE TSIYENO   LIMITE
# 37            LONGITUDE                VILLAGE KINGONGA   LIMITE
# 38            LONGITUDE          EGLISE FEPACO/KINGONGA       IP
# 39            LONGITUDE                       EP MEDITA       EP
# 40            LONGITUDE               EGLISE CATHOLIQUE       IP
# 41            LONGITUDE                  SAVANE MAKONDO  REP GEO
# 42   MUSANDA NGUBA HENZ                  SAVANE MAKONDO  REP GEO
# 43              MAKENZI                  SAVANE MAKONDO  REP GEO
# 44              KITENDA                  SAVANE MAKONDO  REP GEO
# 45  2019-07-27 00:00:00                  SAVANE MAKONDO  REP GEO
# 46             FM    47                  SAVANE MAKONDO  REP GEO
# 47             FM    47                  SAVANE MAKONDO  REP GEO
# 48             FM    47                  VILLAGE KIKOBO  VILLAGE
# 49             FM    47            EGLISE FEPACO KIKOBO       IP
#
#                                                   5  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                       OBSERVATION
# 6                                       OBSERVATION
# 7                                       OBSERVATION
# 8                                       OBSERVATION
# 9                               G:  33         F:41
# 10                              G:  50         F:58
# 11                              G:  50         F:58
# 12                              G:   28        F:39
# 13                              G:   28        F:39
# 14                              G:86           F:74
# 15                              G:86           F:74
# 16                           G: 124          F: 137
# 17                              G:  15        F: 37
# 18                               G:  99       F: 65
# 19                               G:  99       F: 65
# 20  INF: 5  ACC:2  autres: 3 Mocroscope: 1 lits : 5
# 21  INF: 5  ACC:2  autres: 3 Mocroscope: 1 lits : 5
# 22                              G: 23          F:31
# 23                              G: 23          F:31
# 24                              G: 23          F:31
# 25                              G: 23          F:31
# 26                              G: 23          F:31
# 27                              G: 23          F:31
# 28                              G: 23          F:31
# 29                              G: 23          F:31
# 30                                  INF 1, AUXILL 1
# 31                                  INF 1, AUXILL 1
# 32                                  INF 1, AUXILL 1
# 33                            G= 35            F=30
# 34                              G:   42        F:60
# 35                              G:   42        F:60
# 36                    LIMITES AS BAMBA & AS MAKENZI
# 37                    LIMITES AS BAMBA & AS KITENDA
# 38                    LIMITES AS BAMBA & AS KITENDA
# 39                            G= 43            F=57
# 40                            G= 43            F=57
# 41                            G= 43            F=57
# 42                            G= 43            F=57
# 43                            G= 43            F=57
# 44                            G= 43            F=57
# 45                            G= 43            F=57
# 46                            G= 43            F=57
# 47                            G= 43            F=57
# 48                            G= 43            F=57
# 49                            G= 43            F=57
#
#                                  6              7           8  \
# 0   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 1   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 2   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 3   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 4   TRAVAIL DU TERRAIN ZONE RURALE            NaN         NaN
# 5                       TERRITOIRE        SECTEUR  GROUPEMENT
# 6                    KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 7                    KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 8                    KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 9                    KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 10                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 11                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 12                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 13                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 14                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 15                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 16                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 17                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 18                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 19                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 20                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 21                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 22                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 23                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 24                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 25                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 26                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 27                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 28                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 29                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 30                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 31                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 32                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 33                   KASONGO LUNDA  KASONGO LUNDA   MWANA UTA
# 34                   KASONGO LUNDA        KINGULU      POKOSO
# 35                   KASONGO LUNDA        KINGULU      POKOSO
# 36                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 37                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 38                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 39                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 40                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 41                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 42                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 43                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 44                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 45                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 46                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 47                   KASONGO LUNDA  KASONGO LUNDA      POKOSO
# 48                   KASONGO LUNDA  KASONGO LUNDA      KIKOBO
# 49                   KASONGO LUNDA  KASONGO LUNDA      KIKOBO
#
#                      9             10
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
# 5         APPARTENANCE  ACCESSIBILITE
# 6         APPARTENANCE       VEHICULE
# 7           CATHOLIQUE       VEHICULE
# 8     CONV PROTESTANTE       VEHICULE
# 9                 ETAT       VEHICULE
# 10   CONV KIMBANGUISTE       VEHICULE
# 11  TEMOINS DE JEHOVAH       VEHICULE
# 12                ETAT       VEHICULE
# 13                ETAT       VEHICULE
# 14                ETAT       VEHICULE
# 15                ETAT       VEHICULE
# 16                ETAT       VEHICULE
# 17    CONV PROTESTANTE       VEHICULE
# 18    CONV PROTESTANTE       VEHICULE
# 19    CONV PROTESTANTE       VEHICULE
# 20                ETAT       VEHICULE
# 21          CATHOLIQUE       VEHICULE
# 22    CONV PROTESTANTE       VEHICULE
# 23    CONV PROTESTANTE       VEHICULE
# 24    CONV PROTESTANTE       VEHICULE
# 25    CONV PROTESTANTE       VEHICULE
# 26              REVEIL       VEHICULE
# 27              REVEIL       VEHICULE
# 28              REVEIL       VEHICULE
# 29              REVEIL       VEHICULE
# 30                ETAT       VEHICULE
# 31                ETAT       VEHICULE
# 32              REVEIL       VEHICULE
# 33          PROTESTANT       VEHICULE
# 34          PROTESTANT       VEHICULE
# 35          PROTESTANT       VEHICULE
# 36          PROTESTANT       VEHICULE
# 37          PROTESTANT       VEHICULE
# 38              REVEIL       VEHICULE
# 39          PROTESTANT       VEHICULE
# 40         CONV CATHOL       VEHICULE
# 41         CONV CATHOL       VEHICULE
# 42         CONV CATHOL       VEHICULE
# 43         CONV CATHOL       VEHICULE
# 44         CONV CATHOL       VEHICULE
# 45         CONV CATHOL       VEHICULE
# 46         CONV CATHOL       VEHICULE
# 47         CONV CATHOL       VEHICULE
# 48         CONV CATHOL       VEHICULE
# 49         CONV CATHOL       VEHICULE
